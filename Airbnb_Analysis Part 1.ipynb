# %% [markdown]
#  <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <a href="https://cambriancollege.ca/">
#          <img src="https://secure.cambriancollege.ca/user_content/staff/Advancement/Logo/CC_vert_505.jpg" width="150" align="center">
#     </a>
#
# <h1 align=center><font size = 15>ANA 1005: Enterprise Analytics<br>
#     Final Project
#    </font></h1>
# </div>

# %% [markdown]
# ![singapore1.jpg](attachment:singapore1.jpg)

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Overview</h1>
#
# </div>

# %% [markdown]
# AirBnB is an American company that operates an online marketplace for lodging, primarily homestays for vacation rentals and tourism activities.Airbnb has become a very popular choice among travelers around the world for the kind of unique experiences that they provide and also for presenting an alternative to costly hotels. It is currently present in more than 34000+cities across 190 countries. Customers can make their bookings either through the website application or using the iOS/Android application.
#
# Anybody with an open room or free space can become a host on Airbnb and offer it to global community. It is a good way to provide extra income with minimal effort. It is an easy way to advertise space because the platform has the traffic and a global user base to support it. Airbnb gives hosts an easy way to monetize a space

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Dataset Description</h1>
#
# </div>

# %% [markdown]
# We will explore and Visualize dataset from Airbnb in Singapore for our project. The dataset contains 2175 rows and 16 columns. Where 6 columns are Categorical and 9 columns are Numerical (excluding id). Few columns in the dataset have some missing entries and some have wrong datatypes which need to be fixed like minimum_nights, number_of reviews.

# %% [markdown]
# The list of columns in the dataset and their description:

# %% [markdown]
# - id: A unique number identifying an Airbnb listing.
# - host_id: A unique number identifying an Airbnb host.
# - name: Name of the property
# - host_name: Names of different hosts in the listing.
# - room_type: One of “Entire home/apt”, “Private room”, or “Shared room”
# - neighborhood: Areas or cities in the Region. For some region there is no neighbourhood information.
# - neighborhood_group: Five Regions of the Singapore
# - number_of_reviews:  The number of reviews that a listing has received. Airbnb has said that 70% of visits end up with a   review, so the number of reviews can be used to estimate the number of visits.
# - price: The price in $US
# - minimum_nights
# - Latitude and Longitude: Locations of the place
# - last_review:Date of the review
# - reviews_per_month: reviews done for the month
# - Calculated_hosting_listing_count
# - Availability: no of days available per year.

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Task Description</h1>
#
# </div>

# %% [markdown]
# There are several steps we have to complete to reach to our Analysis:
# - Identify the research questions or hypotheses
# - Access the dataset
# - Review the data to determine the variables to be used in the main
# analysis.
# - inclusion/exclusion criteria
# - Select the appropriate statistical methods and software.
# - Clean the data
# - Impute the missing data
# - rectifying the errors in the data

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Personal Objectives / Questions</h1>
#
# </div>

# %% [markdown]
# - How do prices of listings vary by Region?
# - Which Room Type has the highest demand based on the amount of reviews ?
# - Which Region in Singapore has most number of reviews on their Private Room listings?
# - Which Host has the highest average price for their listing(s)? Does this host have multiple listings?
# - Which host had the most listings on Airbnb ?
# - Which types of properties are the most demanded? OR What is the Proportion of Room Type for each Region?
# - Top 5 Locality with Highest number of listings?
# - In order to increase the standard of accomodation, Airbnb plans to limit listing price to a minimum of 20. How many hosts would this change affect?
# - Due to the ongoing Covid pandemic Airbnb plans to prioritise promotion of listings that have not been reviewed since the start of 2019. What percentage of listings would benefit under this plan?

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Constraints</h1>
#
# </div>

# %% [markdown]
# The dataset had some constraints:
#
# - No specific detail on the Price data regarding price per night, minimum night, discounts available etc.
#
# - Demand with respect to Season could not be determined due to lack of data apart from last_reviews dates.
#
# - No ratings on hosts (reviews are there, but nature of the review is not mentioned)

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Intended Outcomes</h1>
#
# </div>

# %% [markdown]
# - The team intends to utilize python to dissect the AirBnb dataset and uncover insights that are relevant to the objectives set above.
# - Through several data wrangling techniques such as imputation and outlier filtering, the team will prepare the dataset for analysis.
# - The team will produce visualisations to help present the findings in this report as well as a separate Powerpoint presentation.

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Foreseeable Challenge</h1>
#
# </div>

# %% [markdown]
# - The dataset may have insufficient numerical data to conduct analysis with.
# - The python workbook may not be in sync with the finalised word report.
# - The team may encounter minor issues when entering the file path and successfully read the dataset.
# - Different time commitments from the team means meeting together over zoom could be challenging at times.
# - The data could be in a unfamiliar format.
# - The datasets may not satisfy all the requirements for the coursework.
# - Team members may accidentally make changes to the report and render analysis and visualations unusable.
# - The dataset may not contain sufficient information to satisfy all the needs of the intended audience.

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Needs Of the Intended Audience</h1>
#
# </div>

# %% [markdown]
# - The intended audience is interested in securing accomodation in Singapore through AirBnb.
# - The intended audience is likely from outside Singapore and therefore not familiar with the geography of the city as well as the pricing expectations on short term accomodations.
# - The intended audience would like information on reputable hosts, the types of accommodation, availability, previous feedback, and the location of their accommodation relative to major tourist attractions.

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Loading the Data</h1>
#
# </div>

# %% [markdown]
# For this project, we are using jupyter notebook IDE with a python programming language to write our script.Before we are able to load the data into our IDE, first we need to import various external libraries/modules that needed for visualization and analysis.

# %% [markdown]
# ### Python Libraries

# %%
#Import Python Libraries
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from scipy.stats import shapiro
# explicitly require this experimental feature
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from plotnine import *
from statsmodels.graphics.gofplots import qqplot

#to make the interactive maps
import folium
from folium.plugins import FastMarkerCluster
#import geopandas as gpd
from branca.colormap import LinearColormap

plotly.offline.init_notebook_mode(connected=True)
import plotly.offline as py
import plotly.graph_objs as go


# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Read Dataset

# %% [markdown]
# To load the dataset, we use pandas library and function to read the CSV file of Singapore Airbnb
# convert it to the DataFrame and check the top 5 index data.

# %%
airbnb = pd.read_excel("project_airbnb.xlsx")
airbnb.head()
# Out:
#       id                                 name  host_id  host_name  \
# 0  49091    COZICOMFORT LONG TERM STAY ROOM 2   266763  Francesca
# 1  50646      Pleasant Room along Bukit Timah   227796    Sujatha
# 2  56334                          COZICOMFORT   266763  Francesca
# 3  71609  Ensuite Room (Room 1 & 2) near EXPO   367042    Belinda
# 4  71896      B&B  Room 1 near Airport & EXPO   367042    Belinda
#
#   neighbourhood_group neighbourhood  latitude  longitude     room_type  price  \
# 0        North Region     Woodlands   1.44255  103.79580  Private room   83.0
# 1      Central Region   Bukit Timah   1.33235  103.78521  Private room   81.0
# 2        North Region     Woodlands   1.44246  103.79667  Private room   69.0
# 3         East Region      Tampines   1.34541  103.95712  Private room  206.0
# 4         East Region      Tampines   1.34567  103.95963  Private room   94.0
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Exploratory Analysis Of The Data</h1>
#
# </div>

# %% [markdown]
# After loading the data now its time to understand the data by using various techniques. First we need to look at how big our dataset. By using shape attribute, we got to know data size from number of rows and columns

# %%
airbnb.shape
# Out:
# (2175, 16)

# %% [markdown]
# Now, we will look at the labels of the columns of the dataset using .columns attribute

# %%
airbnb.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# To get a quick overview of the dataset we used info function to get a concise dataset summary

# %%
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2175 entries, 0 to 2174
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              2175 non-null   int64
#  1   name                            2173 non-null   object
#  2   host_id                         2175 non-null   int64
#  3   host_name                       2175 non-null   object
#  4   neighbourhood_group             2175 non-null   object
#  5   neighbourhood                   2175 non-null   object
#  6   latitude                        2175 non-null   float64
#  7   longitude                       2175 non-null   float64
#  8   room_type                       2175 non-null   object
#  9   price                           2014 non-null   float64
#  10  minimum_nights                  1958 non-null   float64
#  11  number_of_reviews               2174 non-null   float64
# ...

# %% [markdown]
# To know the summary statistics of the dataset we used describe function

# %%
airbnb.describe()
# Out:
#                  id       host_id     latitude    longitude        price  \
# count  2.175000e+03  2.175000e+03  2175.000000  2175.000000  2014.000000
# mean   9.732469e+06  3.142480e+07     1.320105   103.850390   145.433962
# std    4.448004e+06  2.630058e+07     0.034211     0.048107   314.520672
# min    4.909100e+04  5.949800e+04     1.243910   103.665470    15.000000
# 25%    6.340588e+06  1.006438e+07     1.299100   103.834745    60.000000
# 50%    9.802857e+06  2.410864e+07     1.313310   103.850110    94.000000
# 75%    1.356465e+07  4.654559e+07     1.328985   103.882115   158.000000
# max    1.661018e+07  1.095592e+08     1.453280   103.971710  8900.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count     1958.000000        2174.000000        1682.000000
# mean        22.685393          26.649494           0.795981
# std         52.942416          46.377951           1.104883
# min          1.000000           0.000000           0.010000
# ...

# %% [markdown]
# Now, we will see the relation between various columns using correlation function to see how they are correlated with each other.

# %%
df=airbnb.copy()
df.drop(['latitude','longitude'],axis=1,inplace=True)
df.head()
# Out:
#       id                                 name  host_id  host_name  \
# 0  49091    COZICOMFORT LONG TERM STAY ROOM 2   266763  Francesca
# 1  50646      Pleasant Room along Bukit Timah   227796    Sujatha
# 2  56334                          COZICOMFORT   266763  Francesca
# 3  71609  Ensuite Room (Room 1 & 2) near EXPO   367042    Belinda
# 4  71896      B&B  Room 1 near Airport & EXPO   367042    Belinda
#
#   neighbourhood_group neighbourhood     room_type  price  minimum_nights  \
# 0        North Region     Woodlands  Private room   83.0           180.0
# 1      Central Region   Bukit Timah  Private room   81.0            90.0
# 2        North Region     Woodlands  Private room   69.0             NaN
# 3         East Region      Tampines  Private room  206.0             1.0
# 4         East Region      Tampines  Private room   94.0             1.0
#
#    number_of_reviews last_review  reviews_per_month  \
# 0                1.0  2013-10-21               0.01
# ...

# %% [markdown]
# Made a copy of dataset, so that we can drop latitude and longitude column to get better insight of the correlation of different columns.

# %%
c=df.corr()
c
# Out:
#                                       id   host_id     price  minimum_nights  \
# id                              1.000000  0.514868  0.007018       -0.028139
# host_id                         0.514868  1.000000  0.031675        0.032790
# price                           0.007018  0.031675  1.000000        0.025187
# minimum_nights                 -0.028139  0.032790  0.025187        1.000000
# number_of_reviews              -0.106252 -0.042030 -0.032478       -0.104013
# reviews_per_month               0.043786  0.086691 -0.005997       -0.103422
# calculated_host_listings_count -0.035520 -0.228235 -0.008241       -0.063392
# availability_365               -0.063079 -0.063007  0.020473        0.197524
#
#                                 number_of_reviews  reviews_per_month  \
# id                                      -0.106252           0.043786
# host_id                                 -0.042030           0.086691
# ...

# %%
## Generate a mask for the upper triangle
mask = np.triu(np.ones_like(c, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(c, mask=mask)
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the above coorelation matrix we can see that number_of reviews and reviews_per_month are highly correlated column.

# %% [markdown]
# ## Changing datatypes

# %% [markdown]
# Then we will check all the datatype of the columns and check if it already matches our requirements.

# %%
airbnb.dtypes
# Out:
# id                                         int64
# name                                      object
# host_id                                    int64
# host_name                                 object
# neighbourhood_group                       object
# neighbourhood                             object
# latitude                                 float64
# longitude                                float64
# room_type                                 object
# price                                    float64
# minimum_nights                           float64
# number_of_reviews                        float64
# last_review                       datetime64[ns]
# reviews_per_month                        float64
# calculated_host_listings_count             int64
# availability_365                           int64
# dtype: object

# %% [markdown]
# After loading the airbnb dataset we see that minimum_nights and number_of_reviews were identified as float datatype but we converted them to Integers as per our requirement and converted the categorical variables into category type for ease of converting them into dummy variable.

# %%
# Changing Datatype of the columns

airbnb['minimum_nights'] = airbnb['minimum_nights'].astype('Int64')
airbnb['minimum_nights'].dtype

airbnb['number_of_reviews'] = airbnb['number_of_reviews'].astype('Int64')
airbnb['number_of_reviews'].dtype
# Out:
# Int64Dtype()

# %%
#Changing datatype of categorical variable to category for ease of using pd.dummies() in future
airbnb['room_type']=airbnb['room_type'].astype('category')
airbnb['room_type'].dtype
# Out:
# CategoricalDtype(categories=['Entire home/apt', 'Private room', 'Shared room'], ordered=False)

# %%
airbnb['neighbourhood']=airbnb['neighbourhood'].astype('category')
airbnb['neighbourhood'].dtype
# Out:
# CategoricalDtype(categories=['Ang Mo Kio', 'Bedok', 'Bishan', 'Bukit Batok',
#                   'Bukit Merah', 'Bukit Panjang', 'Bukit Timah',
#                   'Central Water Catchment', 'Choa Chu Kang', 'Clementi',
#                   'Downtown Core', 'Geylang', 'Hougang', 'Jurong East',
#                   'Jurong West', 'Kallang', 'Mandai', 'Marine Parade',
#                   'Museum', 'Newton', 'Novena', 'Orchard', 'Outram',
#                   'Pasir Ris', 'Punggol', 'Queenstown', 'River Valley',
#                   'Rochor', 'Sembawang', 'Sengkang', 'Serangoon',
#                   'Singapore River', 'Southern Islands', 'Sungei Kadut',
#                   'Tampines', 'Tanglin', 'Toa Payoh',
#                   'Western Water Catchment', 'Woodlands', 'Yishun'],
# , ordered=False)

# %%
airbnb['neighbourhood_group']=airbnb['neighbourhood_group'].astype('category')
airbnb['neighbourhood_group'].dtype
# Out:
# CategoricalDtype(categories=['Central Region', 'East Region', 'North Region',
#                   'North-East Region', 'West Region'],
# , ordered=False)

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Cleaning the Dataset</h1>
#
# </div>

# %% [markdown]
# The next step is cleaning up the data, the data we load have various faults, such missing value, incomplete data, etc. By doing cleaning up, the data quality will have better quality to be used for further analysis.

# %% [markdown]
# ### Checking the columns with Null Values

# %%
# Checking for null values
airbnb.isnull().any()
# Out:
# id                                False
# name                               True
# host_id                           False
# host_name                         False
# neighbourhood_group               False
# neighbourhood                     False
# latitude                          False
# longitude                         False
# room_type                         False
# price                              True
# minimum_nights                     True
# number_of_reviews                  True
# last_review                        True
# reviews_per_month                  True
# calculated_host_listings_count    False
# availability_365                  False
# dtype: bool

# %% [markdown]
# Using dtypes we found that 6 columns in the dataset has missing values.

# %%
#Number of missing values in the columns
airbnb.isnull().sum()
# Out:
# id                                  0
# name                                2
# host_id                             0
# host_name                           0
# neighbourhood_group                 0
# neighbourhood                       0
# latitude                            0
# longitude                           0
# room_type                           0
# price                             161
# minimum_nights                    217
# number_of_reviews                   1
# last_review                       493
# reviews_per_month                 493
# calculated_host_listings_count      0
# availability_365                    0
# dtype: int64

# %%
total_missing_value_dataset=airbnb.isnull().sum().sum()
total_missing_value_dataset
# Out:
# 1367

# %% [markdown]
# The total Number of missing values in the dataset is 1367

# %% [markdown]
# ## Replacing Null Values

# %% [markdown]
# ### For Numeric Columns

# %% [markdown]
# A common method of imputation with numeric features is to replace missing values with the mean of the feature’s non-missing values. If the data have outliers, you may want to use the median instead.

# %% [markdown]
# PRICE - We used Median Imputation as the price has outliers

# %%
# For price column using median Imputation as price has outliers which will affect our analysis
price_median = airbnb.price.median(axis=0)
print(price_median)
# Out:
# 94.0

# %%
airbnb['price'].replace(np.nan, price_median, inplace=True)
#check if still any valuse not replaced
airbnb['price'].isnull().any()
# Out:
# False

# %% [markdown]
# MINIMUM NIGHTS

# %%
#For Minimum_nights using mean imputation
nights_mean=airbnb['minimum_nights'].astype('float').mean(axis=0)
nights_mean=round(nights_mean,0)
nights_mean
# Out:
# 23.0

# %%
airbnb['minimum_nights'].replace(np.nan,nights_mean, inplace=True)
#check if still any valuse not replaced
airbnb['minimum_nights'].isnull().any()
# Out:
# False

# %% [markdown]
# LAST REVIEW

# %% [markdown]
# For categorical Variable Last_Review we are removing errors which is in this case a blank or NaT is replaced by most frequently occuring date which will not affect our analysis

# %%
airbnb = airbnb.dropna( how='any',
                    subset=['last_review'])

# %%
#check if still any valuse not replaced
airbnb['last_review'].isnull().any()
# Out:
# False

# %% [markdown]
# REVIEWS PER MONTH

# %%
#For reviews per month using mean imputation
monthReview_mean=airbnb['reviews_per_month'].astype('float').mean(axis=0)
monthReview_mean=round(monthReview_mean,2)
monthReview_mean
# Out:
# 0.8

# %%
airbnb['reviews_per_month'].replace(np.nan,monthReview_mean, inplace=True)
#check if still any valuse not replaced
airbnb['reviews_per_month'].isnull().any()
# Out:
# False

# %% [markdown]
# NUMBER OF REVIEWS

# %% [markdown]
# For Number of Reviews we are using Linear Regression imputation as reviews per month and number of reviews are highly correlated

# %%
missing_value=airbnb[['number_of_reviews','reviews_per_month']]

# %%
imp = IterativeImputer(max_iter=10, random_state=0)
imp.fit(missing_value)
imputed=imp.transform(missing_value)
airbnb['number_of_reviews']=imputed

# %%
airbnb['number_of_reviews'].isnull().any()
# Out:
# False

# %% [markdown]
# ## For Categorical Variable

# %%
# For name we will imputate using most frequent value
most_freq=airbnb['name'].value_counts().idxmax()  #gives most frequent used value
most_freq
# Out:
# 'Single Capsule For 1 (Free Breakfast)'

# %%
airbnb['name'].replace(np.nan,most_freq, inplace=True)

# %%
airbnb['name'].isnull().any()
# Out:
# False

# %% [markdown]
# After applying all kind of imputations to the missing value we have now replaced all the missing values, there is no NaN value in the dataset at this stage. Though we still need to work on outliers.

# %% [markdown]
# ## Check the distribution of Numerical Values

# %%
copy_airbnb=airbnb.copy()
copy_airbnb.drop(['latitude','longitude','id','host_id'],axis=1,inplace=True)

# %%
copy_airbnb.hist(figsize=(15,10))
plt.tight_layout()
plt.show()

# %% [markdown]
# As we can see that none of the numerical variable is normally distributed and most of them are right skewed or positively skewed

# %% [markdown]
# ## Functions to be used in the analysis

# %% [markdown]
# We created two functions statistics_outlier and outliers_number to find out which columns have outliers and how many outliers are there in each column

# %%
def outliers_number(mySeries, upperOutlier, lowerOutlier):
    return sum((mySeries > upperOutlier.loc[mySeries.name, ]) | (mySeries < lowerOutlier.loc[mySeries.name,]))

# %%
def statistics_outlier(df):
    numericalDescribe = (df.describe().T).round(decimals=3) #transpose the rows to column of the out of decribe()
    
    # Calculate outliers using this formula: first quartile – 1.5·IQR > outlier > third quartile + 1.5·IQR
    numericalDescribe['IQR'] = numericalDescribe['75%'] - numericalDescribe['25%']
    numericalDescribe['outliers'] = (numericalDescribe['max'] > (numericalDescribe['75%'] + (1.5 * numericalDescribe['IQR']))) \
                            | (numericalDescribe['min'] < (numericalDescribe['25%'] - (1.5 * numericalDescribe['IQR'])))
    
    
    #This part will give number of outliers (optional)
    # Calculate IQR for each column of the dataframe.
    IQR = df.quantile(.75) - df.quantile(.25)
    
    # Calculate the upper and lower outlier values
    upperOutlier = df.quantile(.75) + (1.5 * (IQR))
    lowerOutlier = df.quantile(.25) - (1.5 * (IQR))
    
    # Store the result in a new column
    numericalDescribe['num_outliers'] = df.apply(outliers_number, args=(upperOutlier, lowerOutlier))
    numericalDescribe.sort_values('num_outliers', ascending=False, inplace=True)

    return numericalDescribe

# %% [markdown]
# ## Outliers

# %%
## checking for outliers by calling the function
df_airbnb=airbnb.copy()
df_airbnb=df_airbnb.select_dtypes(include=np.number)

# convert all these to float64
df_airbnb = df_airbnb.astype(float)

stats_df=statistics_outlier(df_airbnb)
stats_df
# Out:
#                                  count          mean           std        min  \
# calculated_host_listings_count  1682.0  2.340500e+01  4.171800e+01      1.000
# minimum_nights                  1682.0  1.919100e+01  4.089700e+01      1.000
# longitude                       1682.0  1.038510e+02  4.600000e-02    103.665
# latitude                        1682.0  1.318000e+00  3.200000e-02      1.244
# reviews_per_month               1682.0  7.960000e-01  1.105000e+00      0.010
# number_of_reviews               1682.0  3.444500e+01  5.011800e+01      1.000
# price                           1682.0  1.274720e+02  2.036610e+02     18.000
# host_id                         1682.0  2.932296e+07  2.581504e+07  59498.000
# id                              1682.0  9.631227e+06  4.546603e+06  49091.000
# availability_365                1682.0  1.979570e+02  1.493380e+02      0.000
#
#                                         25%           50%           75%  \
# ...

# %% [markdown]
# From the above output, we can clearly see that the price column and couple of others have outliers. Using subject matter expertise, we must investigate these outliers individually. For instance the host_listings and minimum_nights have absurdly high values which could be an error on the part of the owner in entering these values. Alternatively, these could be special properties which are not open for all customers but reserved for people who want to sub-lease these properties.

# %% [markdown]
# ### Outliers for price is removed using IQR method as this method is used mostly for skewed distribution.
# Reference:https://www.analyticsvidhya.com/blog/2021/05/feature-engineering-how-to-detect-and-remove-outliers-with-python-code/

# %%
#Calculate IQR for each column of the dataframe.
IQR = airbnb['price'].quantile(.75) - airbnb['price'].quantile(.25)

    
    # Calculate the upper and lower outlier values
maximum= airbnb['price'].quantile(.75) + (1.5 * (IQR))
minimum = airbnb['price'].quantile(.25) - (1.5 * (IQR))
    
    
airbnb = airbnb[(df_airbnb['price'] > minimum) & (airbnb['price'] < maximum)]

# %%
#box plot to show outliers removed
sns.boxplot(airbnb['price'])
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='price'>

# %% [markdown]
# ## Transformation of DATA

# %% [markdown]
# ## Checking For Skewness

# %% [markdown]
# If the skewness is between -0.5 and 0.5, the data are fairly symmetrical
# · If the skewness is between -1 and — 0.5 or between 0.5 and 1, the data are moderately skewed
# · If the skewness is less than -1 or greater than 1, the data are highly skewed

# %%
airbnb.skew(axis = 0)
# Out:
# id                               -0.170464
# host_id                           1.202374
# latitude                          1.631206
# longitude                        -0.618065
# price                             0.949066
# minimum_nights                    4.042718
# number_of_reviews                 2.481890
# reviews_per_month                 2.301574
# calculated_host_listings_count    2.717481
# availability_365                 -0.183396
# dtype: float64

# %% [markdown]
# According to the skewness rule, the columns minimum_nights , number_of reviews,calculated_host_listing_counts are highly skewed as skewness is greater than 1.
#
# To be noted that Price skewness has reduced from 24 to 0.94 due to removal of outliers.

# %%
qqplot(airbnb['price'], line='s')
plt.show()

# %% [markdown]
# Reference for which transformation to use: https://towardsdatascience.com/types-of-transformations-for-better-normal-distribution-61c22668d3b9

# %% [markdown]
# ## Number of Reviews

# %%
qqplot(airbnb['number_of_reviews'], line='s')
plt.show()

# %%
airbnb['number_of_reviews']=stats.boxcox(airbnb['number_of_reviews'])[0]


airbnb['number_of_reviews'].skew()
# Out:
# -0.010172854649881352

# %% [markdown]
# Box-cox transformation works pretty well for many data natures.Here, we noticed that the Box-cox function reduced the skewness and it is almost equal to zero. Worked well ;)

# %%
qqplot(airbnb['number_of_reviews'], line='s')
plt.show()

# %% [markdown]
# ## Host_listing_counts

# %%
qqplot(airbnb['calculated_host_listings_count'], line='s')
plt.show()

# %%
airbnb['calculated_host_listings_count']=stats.boxcox(airbnb['calculated_host_listings_count'])[0]


airbnb['calculated_host_listings_count'].skew()
# Out:
# 0.12985974994422472

# %% [markdown]
# Below graph shows the skewness is removed to much an extent

# %%
qqplot(airbnb['calculated_host_listings_count'], line='s')
plt.show()

# %% [markdown]
# ## Minimum_Nights

# %% [markdown]
# Histogram below shows the skewness of minimum nights column

# %%
sns.distplot(airbnb['minimum_nights'])
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='minimum_nights', ylabel='Density'>

# %%
airbnb['minimum_nights']=np.log(airbnb['minimum_nights'])
airbnb['minimum_nights'].skew()
# Out:
# 0.6885828999134472

# %%
sns.distplot(airbnb['minimum_nights']);
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %% [markdown]
# The above graph shows that skewness is reduced from 4.00 to 0.71 and there are no more outliers for the minimum nights now.

# %% [markdown]
# ## Outliers Check

# %%
df_airbnb=airbnb.copy()
df_airbnb=df_airbnb.select_dtypes(include=np.number)

# convert all these to float64
df_airbnb = df_airbnb.astype(float)

stats_df=statistics_outlier(df_airbnb)
stats_df
# Out:
#                                  count          mean           std        min  \
# longitude                       1588.0  1.038510e+02  4.700000e-02    103.665
# latitude                        1588.0  1.318000e+00  3.200000e-02      1.249
# reviews_per_month               1588.0  7.920000e-01  1.082000e+00      0.010
# host_id                         1588.0  2.961811e+07  2.586368e+07  59498.000
# price                           1588.0  1.053480e+02  5.951200e+01     18.000
# id                              1588.0  9.671317e+06  4.540926e+06  49091.000
# minimum_nights                  1588.0  1.675000e+00  1.527000e+00      0.000
# number_of_reviews               1588.0  2.631000e+00  1.613000e+00      0.000
# calculated_host_listings_count  1588.0  1.413000e+00  1.143000e+00      0.000
# availability_365                1588.0  1.977240e+02  1.499690e+02      0.000
#
#                                         25%           50%           75%  \
# ...

# %% [markdown]
# ## Binning the Price Variable to have better insight

# %% [markdown]
# We would like 3 bins of equal size bandwidth so we use numpy's linspace(start_value, end_value, numbers_generated function. We need to set the start_value of the function to be the min(airbnb["price"]), the end_value to be the max(airbnb["price"]).We also need to set the number of bins needed.

# %%
bins = np.linspace(min(airbnb["price"]), max(airbnb["price"]), 4)
bins
# Out:
# array([ 18.        , 105.66666667, 193.33333333, 281.        ])

# %%
#group names:
group_names = ['Low', 'Medium', 'High']

# %%
#We apply the function "cut" the determine what each value of "df['horsepower']" belongs to.
airbnb['price_range'] = pd.cut(airbnb['price'], bins, labels=group_names, include_lowest=True )
airbnb[['price','price_range']].head(100)
# Out:
#      price price_range
# 0     83.0         Low
# 1     81.0         Low
# 2     69.0         Low
# 3    206.0        High
# 4     94.0         Low
# ..     ...         ...
# 129  250.0        High
# 130   99.0         Low
# 131   89.0         Low
# 132  139.0      Medium
# 133  281.0        High
#
# [100 rows x 2 columns]

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Analysis</h1>
# </div>

# %% [markdown]
# ## 1. How do prices of listings vary by location or Region?

# %%
#new subset for question 1 only using 3 relevant columns
airbnb1 = airbnb[['price','neighbourhood','neighbourhood_group']]
#subset grouped by neighbourhood group, showing basic price statistics rounded to 2 decimal places
round(airbnb1.groupby('neighbourhood_group').agg({'price': ['mean', 'min', 'max', 'median']}),2)
# Out:
#                       price
#                        mean   min    max median
# neighbourhood_group
# Central Region       111.78  18.0  281.0   94.0
# East Region           99.63  26.0  260.0   90.0
# North Region          71.56  25.0  187.0   54.0
# North-East Region     74.52  25.0  235.0   65.0
# West Region           81.52  18.0  258.0   60.0

# %%
ggplot(aes(x=airbnb['price'], fill=airbnb['neighbourhood_group']))+geom_density(alpha = 0.8)+ labs(x= "Price",y='Density')
# Out:
# <ggplot: (140630602301)>

# %% [markdown]
# ## Interpretation

# %% [markdown]
# ### The Central region has the highest prices. The East Region has a lower mean price than the Central Region but it has the same median price as the Central Region. The North Region has the lowest prices both in terms of median prices and mean prices.

# %% [markdown]
# ## 2. Which Room Type has the highest demand based on the number of reviews ?

# %%
#sub dataset for the question. Number of reviews grouped by the room types, showing Max, Min and Mean number of reviews for the rooms.
#airbnb2 = airbnb[['room_type','number_of_reviews']]
airbnb2=airbnb.groupby('room_type').agg({'number_of_reviews': [ 'mean']})
airbnb2
# Out:
#                 number_of_reviews
#                              mean
# room_type
# Entire home/apt          2.910730
# Private room             2.377315
# Shared room              2.906716

# %%
#list for both labels and colors
pie_labels = ['Entire Home/Apt','Private Room','Shared Room']
pie_colors = ['seagreen','teal','blue']

#explodes the female part out of the pie chart
pie_explode = (0.2, 0,0) 
plt.figure(figsize=(12,12))

#adding the data, ravel() is used to flattened the array (1-d array)
plt.pie(np.array(airbnb2).ravel(),labels=pie_labels,autopct='%1.2f%%',explode=pie_explode,colors=pie_colors)

#setting title
plt.title('Room Type in demand based on the number of Reviews')

#displays the graph
plt.show()

# %% [markdown]
# ## Interpretation

# %% [markdown]
# ### Entire home/apt has the highest demand because it has the most reviews on average. Private Rooms and Shared Rooms both average 22-25 reviews per listing, which is significantly lower than the 33 reviews per listing for Entire home/apt.

# %% [markdown]
# ## 3. Which Region in Singapore has most number of reviews on their Private Room listings?

# %%
#sub dataset for question3 grouped by neighbourhood group and mean number of reviews, where room type is "Private room"
airbnb3 = airbnb[['number_of_reviews','room_type','neighbourhood_group']]
round(airbnb3[airbnb3['room_type']== "Private room"].groupby('neighbourhood_group').mean(),2)

# %% [markdown]
# ## Interpretation

# %% [markdown]
# ### The East region have a significantly higher number of reviews than the rest of the regions on their Private room listings.

# %% [markdown]
# ## 4. Which Host has the highest average price for their listing(s)? Does this host have multiple listings?

# %%
#sub dataset for question 4 and grouped by host name and showing average price and number of listings
airbnb4 = airbnb[['host_name','price', 'calculated_host_listings_count']]
airbnb4_updated = round(airbnb4.groupby(['host_name','calculated_host_listings_count']).mean(),2)
airbnb4_updated.sort_values(by='price', ascending=False).head(10)

# %% [markdown]
# ## Interpretation

# %% [markdown]
# ### Vinn and Sara both have the higest average listing price in Singapore, averaging 244 per room. Vinn has 45 listings whereas Sara has 3.

# %% [markdown]
# ## 5. Which host had the most listings on Airbnb ?

# %%
top_host_name = airbnb['host_name'].value_counts().head(10)

# %%
sns.set(rc={'figure.figsize':(10,8)})
viz_bar = top_host_name.plot(kind='bar')
viz_bar.set_title('Hosts with the most listings in Singapore')
viz_bar.set_xlabel('Host IDs')
viz_bar.set_ylabel('Count of listings')
# Out:
# Text(0, 0.5, 'Count of listings')

# %% [markdown]
# ## Interpretation

# %% [markdown]
# ### From the above graph we can say that the top position is shared by two hosts Shirley and Alex with most number of listings.

# %% [markdown]
# ## 6. What is the Proportion of Room Type for each Region?

# %%
plt.figure(figsize=(10,6))
sns.countplot(x = "neighbourhood_group",hue = 'room_type',data = airbnb)
plt.title("Room types occupied For Each Region")
plt.show()

# %% [markdown]
# ## Interpretation

# %% [markdown]
# ### We can see the Central Region is the only region that is dominated by the entire home/apt type, with the rest of the region is dominated by private room type.

# %% [markdown]
# ## 7. Locality with Most number of listings

# %%
# Count the occurrence for each Neightbourhood
airbnb['neighbourhood'].value_counts().head()
# Out:
# Kallang    216
# Geylang    210
# Outram     112
# Novena      97
# Bedok       95
# Name: neighbourhood, dtype: int64

# %%
import folium
from folium.plugins import HeatMap
lats = airbnb['latitude'].tolist()
lons = airbnb['longitude'].tolist()
locations = list(zip(lats, lons))

map1 = folium.Map(location=[1.35255,103.82580], zoom_start=11.5)
FastMarkerCluster(data=locations).add_to(map1)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ## Interpretation

# %% [markdown]
# ### From above table and map we can say that neighbourhood with most listings belong to the Central Region of Singapore (Kallang Geylang,Outram,Novena) exception being Bedok from East Region of Singapore

# %% [markdown]
# ## 8. In order to increase the standard of accomodation, Airbnb plans to limit listing price to a minimum of 20. How many hosts would this change affect?

# %%
airbnb[['host_name','price']].sort_values(by='price', ascending=True).head(15)
# Out:
#         host_name  price
# 586           Gao   18.0
# 1147      Meadows   18.0
# 1696        Caleb   19.0
# 1762     Gap Year   19.0
# 523         Caleb   19.0
# 1674        Caleb   19.0
# 1672        Caleb   19.0
# 1742     Gap Year   22.0
# 1141      Meadows   22.0
# 1144      Meadows   22.0
# 1105      Meadows   22.0
# 1145      Meadows   22.0
# 1140      Meadows   22.0
# 940       Meadows   22.0
# 870   Vikneswaran   22.0

# %% [markdown]
# ## Interpretation

# %% [markdown]
# ### The team needs to find out if there are listings that are listed for under 20. These listings will be removed under the proposed plans.There are 13 listings that will be affected by these plans. These listings are currently listed for under 20. Under current plans the price for these listings will have to increase to a minimum of 20 if they are to be remained listed on Airbnb. These listings belong to 10 different hosts.

# %% [markdown]
# ## 9. Due to the ongoing Covid pandemic Airbnb plans to prioritise promotion of listings that have not been reviewed since the start of 2019. What percentage of listings would benefit under this plan?

# %%
date = "2019-1-1"
date2 = airbnb[airbnb["last_review"] <= date]
date2.count()*100/airbnb.count() #obtain percentage
# Out:
# id                                45.025189
# name                              45.025189
# host_id                           45.025189
# host_name                         45.025189
# neighbourhood_group               45.025189
# neighbourhood                     45.025189
# latitude                          45.025189
# longitude                         45.025189
# room_type                         45.025189
# price                             45.025189
# minimum_nights                    45.025189
# number_of_reviews                 45.025189
# last_review                       45.025189
# reviews_per_month                 45.025189
# calculated_host_listings_count    45.025189
# availability_365                  45.025189
# price_range                       45.025189
# dtype: float64

# %% [markdown]
# ## Interpretation

# %% [markdown]
# ###  The team will analyse the dataset and search for listings where their most recent review was before 1st January 2019. These listings would be prioritised under Airbnb's proposal.
# ###  34.78% of all listings on Airbnb Singapore would be prioritised in future promotions if the proposal is given the go-ahead.

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Conclusion</h1>
# </div>

# %% [markdown]
# ### By performing different analysis on the dataset, we’ve identified various new insight on how the Airbnb listings distributed on Singapore, we know where are the listings located, found out the Central Region is dominating the listing number and have the highest price range, which room type is more in demand in each region.
# ### And we can conclude from our analysis that Central Region is dominating in all the aspects It is  understandable because most of the Central Region area is tourism area, such as : Singapore river, Marina PArade, Newton, Rochor, Novena, Kallang, etc.

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Refernces</h1>
# </div>

# %% [markdown]
# https://www.analyticsvidhya.com/blog/2021/05/feature-engineering-how-to-detect-and-remove-outliers-with-python-code/

# %% [markdown]
# https://pandas.pydata.org/

# %% [markdown]
# https://www.analyticsvidhya.com/blog/2015/04/comprehensive-guide-data-exploration-sas-using-python-numpy-scipy-matplotlib-pandas/
